# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm 
import statsmodels.formula.api as smf 
from sklearn.preprocessing import scale, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, roc_curve, mean_squared_error
from sklearn import tree 
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fc7a79f1e501> in <module>
#      23 from sklearn.ensemble import RandomForestClassifier
#      24 from sklearn.ensemble import GradientBoostingClassifier
# ---> 25 from xgboost import XGBClassifier
#      26 from lightgbm import LGBMClassifier
#      27 from warnings import filterwarnings
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
data= pd.read_csv("hmelq.csv")

# %%
df=data.copy()

# %%
df=df.dropna()
df.head()
# Out:
#      bad   loan   mortdue     value   reason  job   yoj  derog  delinq  \
# 153    0  18200   94727.0  136877.0  DebtCon  Mgr  15.0    0.0     0.0
# 154    0  21700   79240.0   96784.0  DebtCon  Mgr   5.0    0.0     0.0
# 155    0  34100  241931.0   36486.0  DebtCon  Mgr   1.0    0.0     2.0
# 156    0   8400   62989.0   76718.0  HomeImp  Mgr   3.0    0.0     2.0
# 157    0  17400   25859.0   43684.0  DebtCon  Mgr  16.0    1.0     0.0
#
#       clage  ninq  clno  debtinc
# 153  168.96   2.0  26.0   36.056
# 154   64.51   6.0  24.0   38.079
# 155  196.01   3.0  50.0   42.459
# 156  131.47   0.0  22.0   29.200
# 157   95.36   1.0  17.0   27.108

# %%
dm=pd.get_dummies(df[['reason','job']])
dm.head()
# Out:
#      reason_DebtCon  reason_HomeImp  job_Mgr  job_Office  job_Other  \
# 153               1               0        1           0          0
# 154               1               0        1           0          0
# 155               1               0        1           0          0
# 156               0               1        1           0          0
# 157               1               0        1           0          0
#
#      job_ProfEx  job_Sales  job_Self
# 153           0          0         0
# 154           0          0         0
# 155           0          0         0
# 156           0          0         0
# 157           0          0         0

# %%
y=df['bad']
x_=df.drop(['reason','job','bad'],axis=1).astype('float64')
X=pd.concat([x_,dm],axis=1)

X.head()
# Out:
#         loan   mortdue     value   yoj  derog  delinq   clage  ninq  clno  \
# 153  18200.0   94727.0  136877.0  15.0    0.0     0.0  168.96   2.0  26.0
# 154  21700.0   79240.0   96784.0   5.0    0.0     0.0   64.51   6.0  24.0
# 155  34100.0  241931.0   36486.0   1.0    0.0     2.0  196.01   3.0  50.0
# 156   8400.0   62989.0   76718.0   3.0    0.0     2.0  131.47   0.0  22.0
# 157  17400.0   25859.0   43684.0  16.0    1.0     0.0   95.36   1.0  17.0
#
#      debtinc  reason_DebtCon  reason_HomeImp  job_Mgr  job_Office  job_Other  \
# 153   36.056               1               0        1           0          0
# 154   38.079               1               0        1           0          0
# 155   42.459               1               0        1           0          0
# 156   29.200               0               1        1           0          0
# 157   27.108               1               0        1           0          0
#
#      job_ProfEx  job_Sales  job_Self
# 153           0          0         0
# 154           0          0         0
# 155           0          0         0
# 156           0          0         0
# 157           0          0         0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

print("X_train", X_train.shape)

print("y_train",y_train.shape)

print("X_test",X_test.shape)

print("y_test",y_test.shape)

training = df.copy()

print("training", training.shape)
# Out:
# X_train (1513, 18)
# y_train (1513,)
# X_test (505, 18)
# y_test (505,)
# training (2018, 13)

# %% [markdown]
# # CART ALGORİTMASI

# %% [markdown]
# MODEL

# %%
cart_model=DecisionTreeClassifier()

# %%
cart_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn import tree
plt.figure(figsize=(45,25))
tree.plot_tree(cart_model);

# %%
y_pred= cart_model.predict(X_train)
#model hatası
np.sqrt(mean_squared_error(y_train,y_pred))
# Out:
# 0.0

# %%
from skompiler import skompile
print(skompile(cart_model.predict).to('python/code'))
# Out:
# ((((((0.0 if x[1] <= 30859.0 else 1.0 if x[3] <= 6.5 else 0.0) if x[9] <=
#     32.76449966430664 else 0.0 if x[3] <= 1.5 else 1.0) if x[0] <= 9050.0 else
#     (((0.0 if x[4] <= 0.5 else 0.0 if x[8] <= 8.0 else 1.0) if x[2] <=
#     45602.0 else 0.0 if x[6] <= 81.6150016784668 else 1.0) if x[0] <=
#     12750.0 else 0.0 if x[6] <= 324.5449981689453 else 1.0) if x[4] <= 3.5 else
#     1.0) if x[2] <= 48600.0 else (1.0 if x[9] <= 37.44599914550781 else 0.0
#     ) if x[6] <= 44.345001220703125 else ((((((1.0 if x[3] <= 4.0 else 0.0 if
#     x[13] <= 0.5 else 1.0) if x[6] <= 60.404998779296875 else ((((1.0 if x[
#     1] <= 68316.0 else 0.0) if x[3] <= 1.5 else 0.0) if x[10] <= 0.5 else (
#     0.0 if x[3] <= 1.0 else 1.0) if x[8] <= 28.0 else 0.0) if x[4] <= 0.5 else
#     1.0 if x[6] <= 160.40499877929688 else 0.0) if x[0] <= 6950.0 else ((((
#     (1.0 if x[9] <= 33.51150035858154 else 0.0) if x[1] <= 38380.5 else (
#     0.0 if x[11] <= 0.5 else 1.0 if x[9] <= 35.37899971008301 else 0.0) if
#     x[5] <= 0.5 else 1.0 if x[6] <= 75.35499954223633 else 0.0) if x[2] <=
#     83763.0 else 0.0 if x[9] <= 24.32099986076355 else 1.0) if x[1] <=
#     61462.5 else 1.0 if x[0] <= 10200.0 else 1.0 if x[7] <= 0.5 else 0.0) if
#     x[2] <= 86023.5 else 0.0) if x[6] <= 95.79000091552734 else (((((1.0 if
#     x[0] <= 10300.0 else 0.0 if x[1] <= 41692.0 else 1.0) if x[9] <=
#     40.778499603271484 else 1.0) if x[1] <= 42965.5 else 0.0 if x[0] <=
#     18350.0 else ((0.0 if x[9] <= 36.092498779296875 else 1.0 if x[6] <=
#     241.3499984741211 else 0.0) if x[0] <= 18650.0 else ((1.0 if x[6] <=
#     157.54999542236328 else 0.0) if x[8] <= 16.5 else 0.0) if x[8] <= 41.5 else
#     1.0 if x[2] <= 199560.0 else 0.0) if x[6] <= 323.1000061035156 else 1.0
#     ) if x[3] <= 3.5 else ((((0.0 if x[9] <= 34.61300086975098 else 1.0 if
#     x[9] <= 34.65450096130371 else 0.0) if x[0] <= 22700.0 else ((0.0 if x[
#     10] <= 0.5 else 1.0) if x[0] <= 22850.0 else 0.0) if x[8] <= 33.5 else
#     1.0) if x[17] <= 0.5 else 0.0 if x[3] <= 12.5 else 1.0) if x[9] <=
#     35.932498931884766 else 1.0) if x[9] <= 35.974998474121094 else 0.0) if
#     x[12] <= 0.5 else ((((0.0 if x[9] <= 27.679999351501465 else 1.0) if x[
#     9] <= 27.792499542236328 else 0.0) if x[4] <= 0.5 else 1.0 if x[6] <=
#     145.6099967956543 else 0.0) if x[0] <= 44650.0 else 1.0) if x[8] <=
#     30.0 else 1.0) if x[9] <= 43.70450019836426 else (0.0 if x[0] <=
#     14200.0 else 1.0) if x[9] <= 44.61199951171875 else 0.0) if x[5] <= 1.5
#      else (1.0 if x[0] <= 5400.0 else 0.0) if x[1] <= 73471.0 else 1.0 if x
#     [9] <= 31.463000297546387 else (1.0 if x[15] <= 0.5 else 0.0) if x[1] <=
#     85129.5 else 0.0 if x[3] <= 21.5 else 1.0) if x[8] <= 60.0 else 1.0) if
#     x[6] <= 901.3450012207031 else 1.0) if x[7] <= 3.5 else (1.0 if x[2] <=
#     69583.0 else (0.0 if x[13] <= 0.5 else 0.0 if x[4] <= 0.5 else 1.0) if
#     x[1] <= 107767.0 else 1.0 if x[9] <= 36.91349983215332 else 0.0 if x[9] <=
#     44.377498626708984 else 1.0) if x[5] <= 0.5 else 1.0 if x[0] <= 23500.0
#      else 0.0) if x[2] <= 490456.0 else 1.0) if x[5] <= 3.5 else 1.0 if x[8
#     ] <= 33.0 else 0.0 if x[1] <= 62489.5 else 1.0) if x[9] <=
#     45.48349952697754 else 1.0)

# %% [markdown]
# TAHMİN

# %%
x=2

# %%
((((((0.0 if x[1] <= 30859.0 else 1.0 if x[3] <= 6.5 else 0.0) if x[9] <= 
    32.76449966430664 else 0.0 if x[3] <= 1.5 else 1.0) if x[0] <= 9050.0 else
    (((0.0 if x[4] <= 0.5 else 0.0 if x[8] <= 8.0 else 1.0) if x[2] <= 
    45602.0 else 0.0 if x[6] <= 81.6150016784668 else 1.0) if x[0] <= 
    12750.0 else 0.0 if x[6] <= 324.5449981689453 else 1.0) if x[4] <= 3.5 else
    1.0) if x[2] <= 48600.0 else (1.0 if x[9] <= 37.44599914550781 else 0.0
    ) if x[6] <= 44.345001220703125 else ((((((1.0 if x[3] <= 4.0 else 0.0 if
    x[13] <= 0.5 else 1.0) if x[6] <= 60.404998779296875 else ((((1.0 if x[
    1] <= 68316.0 else 0.0) if x[3] <= 1.5 else 0.0) if x[10] <= 0.5 else (
    0.0 if x[3] <= 1.0 else 1.0) if x[8] <= 28.0 else 0.0) if x[4] <= 0.5 else
    1.0 if x[6] <= 160.40499877929688 else 0.0) if x[0] <= 6950.0 else ((((
    (1.0 if x[9] <= 33.51150035858154 else 0.0) if x[1] <= 38380.5 else (
    0.0 if x[11] <= 0.5 else 1.0 if x[9] <= 35.37899971008301 else 0.0) if 
    x[5] <= 0.5 else 1.0 if x[6] <= 75.35499954223633 else 0.0) if x[2] <= 
    83763.0 else 0.0 if x[9] <= 24.32099986076355 else 1.0) if x[1] <= 
    61462.5 else 1.0 if x[0] <= 10200.0 else 1.0 if x[7] <= 0.5 else 0.0) if
    x[2] <= 86023.5 else 0.0) if x[6] <= 95.79000091552734 else (((((1.0 if
    x[0] <= 10300.0 else 0.0 if x[1] <= 41692.0 else 1.0) if x[9] <= 
    40.778499603271484 else 1.0) if x[1] <= 42965.5 else 0.0 if x[0] <= 
    18350.0 else ((0.0 if x[9] <= 36.092498779296875 else 1.0 if x[6] <= 
    241.3499984741211 else 0.0) if x[0] <= 18650.0 else ((1.0 if x[6] <= 
    157.54999542236328 else 0.0) if x[8] <= 16.5 else 0.0) if x[8] <= 41.5 else
    1.0 if x[2] <= 199560.0 else 0.0) if x[6] <= 323.1000061035156 else 1.0
    ) if x[3] <= 3.5 else ((((0.0 if x[9] <= 34.61300086975098 else 1.0 if 
    x[9] <= 34.65450096130371 else 0.0) if x[0] <= 22700.0 else ((0.0 if x[
    10] <= 0.5 else 1.0) if x[0] <= 22850.0 else 0.0) if x[8] <= 33.5 else 
    1.0) if x[17] <= 0.5 else 0.0 if x[3] <= 12.5 else 1.0) if x[9] <= 
    35.932498931884766 else 1.0) if x[9] <= 35.974998474121094 else 0.0) if
    x[12] <= 0.5 else ((((0.0 if x[9] <= 27.679999351501465 else 1.0) if x[
    9] <= 27.792499542236328 else 0.0) if x[4] <= 0.5 else 1.0 if x[6] <= 
    145.6099967956543 else 0.0) if x[0] <= 44650.0 else 1.0) if x[8] <= 
    30.0 else 1.0) if x[9] <= 43.70450019836426 else (0.0 if x[0] <= 
    14200.0 else 1.0) if x[9] <= 44.61199951171875 else 0.0) if x[5] <= 1.5
     else (1.0 if x[0] <= 5400.0 else 0.0) if x[1] <= 73471.0 else 1.0 if x
    [9] <= 31.463000297546387 else (1.0 if x[15] <= 0.5 else 0.0) if x[1] <=
    85129.5 else 0.0 if x[3] <= 21.5 else 1.0) if x[8] <= 60.0 else 1.0) if
    x[6] <= 901.3450012207031 else 1.0) if x[7] <= 3.5 else (1.0 if x[2] <=
    69583.0 else (0.0 if x[13] <= 0.5 else 0.0 if x[4] <= 0.5 else 1.0) if 
    x[1] <= 107767.0 else 1.0 if x[9] <= 36.91349983215332 else 0.0 if x[9] <=
    44.377498626708984 else 1.0) if x[5] <= 0.5 else 1.0 if x[0] <= 23500.0
     else 0.0) if x[2] <= 490456.0 else 1.0) if x[5] <= 3.5 else 1.0 if x[8
    ] <= 33.0 else 0.0 if x[1] <= 62489.5 else 1.0) if x[9] <= 
    45.48349952697754 else 1.0)
# Out:
#   File "<ipython-input-27-f73997791716>", line 1
#     (0.0 if x[1] <= 30859.0 else 1.0 if x[3] <= 6.5 else 0.0) if x[9] <=
#                                                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# MODEL TUNING

# %%
cart_params = {"min_samples_split": range(10,50),
               "min_samples_leaf": [10,15,20],
               "max_leaf_nodes": range(4,8)}

# %%
cart_cv_model=GridSearchCV(cart_model,cart_params,cv=10)

# %%
cart_cv_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=None,
#                                               splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'max_leaf_nodes': range(4, 8),
#                          'min_samples_leaf': [10, 15, 20],
#                          'min_samples_split': range(10, 50)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
cart_cv_model.best_params_
# Out:
# {'max_leaf_nodes': 4, 'min_samples_leaf': 10, 'min_samples_split': 10}

# %%
cart_tuned=DecisionTreeRegressor(max_leaf_nodes=4,min_samples_leaf=10,min_samples_split=10)

# %%
cart_tuned.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=4, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=10,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_pred= cart_model.predict(X_train)
np.sqrt(mean_squared_error(y_train,y_pred))
# Out:
# 0.0

# %%
cart_tuned.fit(X_test,y_test)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=4, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=10,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_pred= cart_model.predict(X_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.24776226228758363

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       466
#            1       0.65      0.44      0.52        39
#
#     accuracy                           0.94       505
#    macro avg       0.80      0.71      0.75       505
# weighted avg       0.93      0.94      0.93       505

# %% [markdown]
# # RANDOM FOREST

# %% [markdown]
# MODEL

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestClassifier()

# %%
rf_model.fit(X_train,y_train)
# Out:
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# TAHMİN

# %%
print(skompile(rf_model.predict).to('python/code'))
# Out:
# ((((((0.1 if x[1] <= 54817.5 else 0.0) if x[0] <= 4450.0 else (((0.1 if x[8
#     ] <= 10.0 else 0.0) if x[2] <= 37439.0 else 0.1) if x[0] <= 11000.0 else
#     0.0) if x[2] <= 39783.5 else 0.1 if x[8] <= 2.0 else (((0.0 if x[8] <=
#     18.0 else 0.1) if x[9] <= 7.250499963760376 else (((0.0 if x[9] <=
#     36.38549995422363 else 0.1) if x[8] <= 4.5 else (0.1 if x[6] <=
#     53.65999984741211 else (0.0 if x[0] <= 6850.0 else 0.1) if x[0] <=
#     6950.0 else (((0.1 if x[0] <= 10300.0 else 0.0 if x[9] <=
#     40.778499603271484 else 0.1) if x[7] <= 1.5 else 0.1) if x[1] <=
#     42636.0 else 0.1 if x[6] <= 70.38000106811523 else 0.0) if x[3] <= 3.5 else
#     ((0.1 if x[9] <= 35.35599994659424 else 0.0) if x[1] <= 38380.5 else
#     0.0 if x[0] <= 9450.0 else 0.0 if x[9] <= 30.256999969482422 else 0.1) if
#     x[0] <= 9550.0 else 0.0) if x[17] <= 0.5 else 0.1) if x[2] <= 75277.5 else
#     0.1) if x[2] <= 75362.0 else (((0.0 if x[2] <= 119774.0 else 0.1) if x[
#     0] <= 5600.0 else (0.0 if x[8] <= 34.5 else 0.0 if x[6] <=
#     278.5500030517578 else 0.0 if x[14] <= 0.5 else 0.1) if x[5] <= 1.5 else
#     0.0 if x[9] <= 34.868499755859375 else 0.0 if x[1] <= 71856.5 else 0.1) if
#     x[8] <= 44.5 else 0.0 if x[0] <= 26850.0 else 0.1) if x[5] <= 3.5 else
#     0.0 if x[6] <= 250.60999298095703 else 0.1) if x[12] <= 0.5 else ((((((
#     0.0 if x[2] <= 100384.0 else 0.1) if x[8] <= 17.5 else 0.0) if x[5] <=
#     1.5 else 0.0 if x[3] <= 5.0 else 0.1) if x[7] <= 2.5 else 0.1 if x[2] <=
#     78661.5 else 0.0) if x[8] <= 34.5 else 0.0 if x[2] <= 122471.5 else 0.1
#     ) if x[1] <= 142191.5 else 0.1 if x[6] <= 190.8800048828125 else 0.0 if
#     x[4] <= 0.5 else 0.1) if x[4] <= 1.5 else 0.0 if x[1] <= 62024.0 else
#     0.1) if x[8] <= 60.0 else 0.1) if x[7] <= 3.5 else ((0.0 if x[6] <=
#     47.96500015258789 else 0.1) if x[2] <= 69583.0 else (0.0 if x[2] <=
#     126213.0 else 0.1 if x[2] <= 136352.5 else 0.0) if x[7] <= 11.5 else
#     0.1) if x[5] <= 0.5 else 0.1) if x[5] <= 4.5 else 0.1) if x[9] <=
#     43.70450019836426 else (0.1 if x[13] <= 0.5 else 0.1 if x[11] <= 0.5 else
#     0.0) if x[6] <= 288.3599853515625 else 0.1 if x[1] <= 100846.0 else 0.0
#     ) + (((((0.0 if x[6] <= 65.55999946594238 else ((0.0 if x[1] <= 16220.0
#      else 0.1 if x[1] <= 42568.5 else 0.0) if x[15] <= 0.5 else 0.0) if x[8
#     ] <= 21.5 else 0.0) if x[0] <= 10450.0 else ((0.0 if x[2] <= 42029.5 else
#     0.1) if x[0] <= 12750.0 else 0.0) if x[7] <= 4.0 else 0.1) if x[2] <=
#     51328.0 else (0.1 if x[8] <= 2.5 else (((((((0.1 if x[8] <= 13.0 else
#     0.0) if x[12] <= 0.5 else 0.1) if x[6] <= 94.76499938964844 else 0.0 if
#     x[1] <= 51347.5 else 0.1) if x[6] <= 102.96500015258789 else (((0.0 if
#     x[2] <= 119774.0 else 0.1) if x[0] <= 6050.0 else 0.1) if x[0] <=
#     6150.0 else 0.0) if x[5] <= 2.5 else 0.0 if x[2] <= 92052.0 else 0.1) if
#     x[4] <= 0.5 else 0.0 if x[3] <= 4.5 else 0.0 if x[1] <= 45640.5 else
#     0.1) if x[0] <= 9250.0 else 0.1 if x[9] <= 35.22900104522705 else 0.0) if
#     x[0] <= 9350.0 else ((0.0 if x[8] <= 6.0 else 0.1) if x[8] <= 18.5 else
#     0.0) if x[6] <= 61.2549991607666 else ((((0.1 if x[1] <= 34899.0 else
#     0.0 if x[4] <= 1.0 else 0.1) if x[0] <= 10050.0 else ((0.0 if x[6] <=
#     70.28499984741211 else 0.1) if x[6] <= 70.94499969482422 else (((0.0 if
#     x[1] <= 56646.0 else 0.1) if x[6] <= 94.91500091552734 else 0.0) if x[8
#     ] <= 9.5 else 0.0) if x[6] <= 258.73500061035156 else 0.1 if x[6] <=
#     259.44500732421875 else 0.0 if x[8] <= 34.5 else 0.0 if x[0] <= 22250.0
#      else 0.1) if x[1] <= 115673.0 else 0.1 if x[1] <= 116292.5 else (0.0 if
#     x[8] <= 27.0 else 0.1) if x[3] <= 0.5 else 0.0 if x[5] <= 0.5 else 0.1 if
#     x[6] <= 231.13999938964844 else 0.0) if x[9] <= 41.20899963378906 else
#     0.1 if x[2] <= 64370.5 else 0.1 if x[8] <= 9.0 else ((0.0 if x[6] <=
#     105.125 else 0.1) if x[6] <= 110.36000061035156 else 0.0) if x[2] <=
#     258680.5 else 0.1) if x[5] <= 1.5 else (0.0 if x[2] <= 92535.5 else (
#     0.0 if x[8] <= 21.5 else 0.1) if x[2] <= 102047.0 else 0.1 if x[3] <=
#     0.5 else 0.0) if x[2] <= 125965.0 else 0.0 if x[0] <= 23150.0 else 0.1) if
#     x[8] <= 60.0 else 0.1) if x[7] <= 3.5 else (0.1 if x[2] <= 68812.0 else
#     (0.0 if x[8] <= 42.5 else 0.1 if x[9] <= 36.37399864196777 else 0.0) if
#     x[9] <= 44.377498626708984 else 0.1) if x[5] <= 0.5 else 0.1 if x[0] <=
#     23500.0 else 0.0) if x[1] <= 383586.5 else 0.1) if x[5] <= 4.5 else 0.1
#     ) if x[9] <= 45.13100051879883 else 0.1 if x[6] <= 279.21500396728516 else
#     0.0 if x[7] <= 2.0 else 0.1) + (((((((0.0 if x[3] <= 0.5 else 0.1) if x
#     [8] <= 9.0 else 0.0) if x[2] <= 38319.0 else (0.0 if x[6] <=
#     71.98000144958496 else 0.1) if x[1] <= 40897.0 else 0.0) if x[0] <=
#     12400.0 else ((0.0 if x[6] <= 136.1150016784668 else 0.1) if x[0] <=
#     12750.0 else 0.0) if x[7] <= 4.0 else 0.1) if x[2] <= 48600.0 else ((
#     0.0 if x[8] <= 9.5 else 0.1) if x[2] <= 75256.5 else (0.1 if x[6] <=
#     18.054999351501465 else (0.0 if x[1] <= 60723.0 else 0.1) if x[9] <=
#     35.85949897766113 else 0.0) if x[6] <= 61.31999969482422 else 0.1) if x
#     [6] <= 63.0099983215332 else (0.1 if x[8] <= 2.0 else ((0.1 if x[6] <=
#     91.19999694824219 else 0.0) if x[8] <= 7.5 else (0.1 if x[14] <= 0.5 else
#     0.0) if x[9] <= 17.06999969482422 else ((((((0.0 if x[16] <= 0.5 else
#     0.1 if x[1] <= 62712.5 else 0.0) if x[4] <= 1.5 else 0.1) if x[0] <=
#     7800.0 else 0.1 if x[7] <= 0.5 else 0.0) if x[0] <= 8000.0 else (0.0 if
#     x[6] <= 199.56500244140625 else 0.1 if x[6] <= 199.91500091552734 else
#     0.0 if x[12] <= 0.5 else 0.1 if x[9] <= 29.045499801635742 else 0.0) if
#     x[14] <= 0.5 else (0.0 if x[1] <= 60590.5 else 0.1) if x[8] <= 9.5 else
#     (((((0.1 if x[1] <= 36498.0 else 0.0) if x[0] <= 10250.0 else 0.0) if x
#     [9] <= 41.178998947143555 else 0.0 if x[6] <= 215.37000274658203 else
#     0.1) if x[7] <= 2.5 else 0.1 if x[1] <= 42296.5 else 0.0) if x[1] <=
#     45275.0 else 0.1) if x[1] <= 45755.5 else (0.0 if x[5] <= 1.5 else 0.0 if
#     x[2] <= 113133.0 else 0.1) if x[6] <= 310.9100036621094 else 0.1 if x[6
#     ] <= 313.7250061035156 else 0.0) if x[1] <= 111915.5 else 0.1 if x[1] <=
#     112560.5 else (((0.1 if x[0] <= 23700.0 else 0.0) if x[3] <= 1.5 else
#     0.0 if x[9] <= 42.84699821472168 else 0.0 if x[0] <= 40350.0 else 0.1) if
#     x[5] <= 0.5 else 0.1 if x[6] <= 216.81000518798828 else 0.0) if x[5] <=
#     1.5 else 0.1) if x[9] <= 43.70450019836426 else 0.0 if x[8] <= 39.5 else
#     0.1) if x[7] <= 3.5 else 0.1 if x[2] <= 67881.0 else ((0.0 if x[5] <=
#     0.5 else 0.1 if x[9] <= 34.29100036621094 else 0.0) if x[13] <= 0.5 else
#     0.0 if x[2] <= 115505.0 else 0.1) if x[8] <= 45.5 else 0.1) if x[7] <=
#     12.0 else 0.1) if x[2] <= 297086.0 else 0.0 if x[9] <=
#     42.26499938964844 else 0.1) if x[5] <= 3.5 else 0.1 if x[8] <= 33.0 else
#     0.0) if x[9] <= 45.48349952697754 else 0.1) + (((((((0.1 if x[8] <=
#     28.0 else 0.0 if x[17] <= 0.5 else 0.1) if x[15] <= 0.5 else 0.0) if x[
#     7] <= 6.0 else 0.0) if x[0] <= 10450.0 else 0.1 if x[1] <= 11589.5 else
#     (0.0 if x[15] <= 0.5 else 0.1 if x[0] <= 14600.0 else 0.0) if x[2] <=
#     47950.0 else 0.1 if x[0] <= 12500.0 else 0.0) if x[2] <= 48600.0 else (
#     (0.1 if x[8] <= 2.0 else (((0.1 if x[0] <= 26600.0 else 0.0) if x[7] <=
#     0.5 else 0.0) if x[6] <= 60.404998779296875 else ((((0.1 if x[6] <=
#     230.06499481201172 else 0.0) if x[1] <= 38380.5 else 0.1 if x[6] <=
#     72.375 else (((0.0 if x[3] <= 7.5 else 0.0 if x[1] <= 50509.0 else 0.1 if
#     x[1] <= 65509.5 else 0.0) if x[6] <= 95.20000076293945 else 0.1) if x[6
#     ] <= 98.9749984741211 else 0.0) if x[2] <= 121579.0 else 0.1 if x[11] <=
#     0.5 else 0.0) if x[0] <= 10050.0 else ((0.0 if x[7] <= 2.5 else 0.1 if
#     x[6] <= 117.27000045776367 else 0.0) if x[9] <= 36.8439998626709 else
#     0.1 if x[9] <= 37.1560001373291 else (0.0 if x[0] <= 20800.0 else 0.1 if
#     x[7] <= 0.5 else 0.0) if x[4] <= 0.5 else 0.1) if x[3] <= 3.5 else 0.1 if
#     x[8] <= 7.5 else 0.0 if x[6] <= 280.22999572753906 else 0.1 if x[6] <=
#     280.9599914550781 else 0.0) if x[1] <= 111915.5 else (0.0 if x[8] <=
#     24.5 else 0.1 if x[7] <= 2.5 else 0.0) if x[2] <= 157246.0 else ((0.0 if
#     x[3] <= 12.0 else 0.1) if x[2] <= 167184.0 else 0.1) if x[2] <=
#     167649.5 else 0.0) if x[17] <= 0.5 else 0.1 if x[1] <= 25987.0 else 0.0 if
#     x[6] <= 280.6549987792969 else 0.0 if x[0] <= 21700.0 else 0.1) if x[5] <=
#     1.5 else (0.1 if x[2] <= 64388.5 else (0.1 if x[7] <= 1.0 else 0.0) if
#     x[6] <= 110.70499801635742 else 0.0) if x[2] <= 113133.0 else (0.1 if x
#     [2] <= 115807.0 else 0.0) if x[7] <= 0.5 else 0.1) if x[7] <= 3.5 else
#     (0.1 if x[2] <= 70154.5 else (0.0 if x[3] <= 18.0 else 0.0 if x[2] <=
#     120130.5 else 0.1) if x[7] <= 12.0 else 0.1) if x[5] <= 0.5 else 0.1) if
#     x[1] <= 383586.5 else 0.1) if x[5] <= 3.5 else 0.1) if x[9] <=
#     44.460500717163086 else (0.1 if x[2] <= 111250.0 else 0.0) if x[8] <=
#     18.0 else 0.1 if x[13] <= 0.5 else 0.1 if x[6] <= 174.97500228881836 else
#     0.0) + ((((0.0 if x[3] <= 4.5 else 0.1 if x[9] <= 41.54599952697754 else
#     0.0) if x[0] <= 5200.0 else 0.1 if x[8] <= 2.5 else ((((((0.0 if x[6] <=
#     166.56999588012695 else 0.1) if x[3] <= 3.0 else 0.1) if x[0] <= 9250.0
#      else 0.1) if x[0] <= 10250.0 else 0.0) if x[9] <= 40.83449935913086 else
#     0.1) if x[13] <= 0.5 else 0.1) if x[8] <= 9.5 else 0.1 if x[6] <=
#     43.525001525878906 else (0.1 if x[14] <= 0.5 else 0.0) if x[9] <=
#     13.744999885559082 else (((((0.0 if x[12] <= 0.5 else (0.0 if x[8] <=
#     13.5 else 0.1) if x[8] <= 15.0 else 0.0 if x[4] <= 0.5 else 0.1 if x[0] <=
#     11500.0 else 0.0) if x[14] <= 0.5 else (((0.1 if x[1] <= 38380.5 else
#     0.1 if x[3] <= 2.5 else 0.0) if x[0] <= 9400.0 else (0.1 if x[1] <=
#     29614.0 else 0.0 if x[0] <= 23050.0 else 0.0 if x[8] <= 21.0 else 0.1) if
#     x[3] <= 2.5 else 0.0) if x[9] <= 33.19499969482422 else 0.1) if x[9] <=
#     33.41200065612793 else ((0.0 if x[5] <= 0.5 else 0.1 if x[9] <=
#     36.35150146484375 else 0.0) if x[6] <= 94.76499938964844 else 0.1) if x
#     [6] <= 95.79000091552734 else 0.0 if x[1] <= 93870.5 else 0.1 if x[6] <=
#     153.25499725341797 else 0.0) if x[1] <= 111915.5 else 0.1 if x[1] <=
#     112456.5 else ((((0.1 if x[11] <= 0.5 else 0.0) if x[8] <= 18.5 else
#     0.0) if x[3] <= 11.5 else 0.0 if x[8] <= 24.0 else 0.1) if x[2] <=
#     171697.5 else 0.1) if x[2] <= 172009.5 else 0.0) if x[17] <= 0.5 else
#     0.1 if x[2] <= 80481.5 else 0.0 if x[6] <= 280.6549987792969 else 0.0 if
#     x[10] <= 0.5 else 0.1) if x[7] <= 3.5 else (0.1 if x[2] <= 69583.0 else
#     0.0 if x[13] <= 0.5 else 0.0 if x[3] <= 12.5 else 0.1) if x[5] <= 0.5 else
#     0.1) if x[1] <= 384643.0 else 0.1) if x[5] <= 1.5 else (0.0 if x[8] <=
#     13.5 else 0.1 if x[0] <= 18900.0 else 0.0 if x[3] <= 12.0 else 0.1) if
#     x[1] <= 48327.0 else (((0.1 if x[6] <= 31.249999523162842 else 0.0) if
#     x[5] <= 2.5 else 0.1) if x[6] <= 153.82000732421875 else 0.1 if x[3] <=
#     0.5 else 0.0) if x[2] <= 125965.0 else 0.1) if x[9] <=
#     44.460500717163086 else 0.1 if x[6] <= 239.91500091552734 else 0.0 if x
#     [3] <= 17.0 else 0.1) + (((((0.0 if x[3] <= 6.5 else 0.1) if x[0] <=
#     4100.0 else (0.1 if x[14] <= 0.5 else 0.0) if x[9] <= 7.250499963760376
#      else ((0.1 if x[0] <= 11950.0 else 0.0) if x[6] <= 44.345001220703125 else
#     ((0.1 if x[6] <= 176.0449981689453 else 0.0 if x[9] <=
#     32.954999923706055 else 0.1) if x[0] <= 9250.0 else (((0.1 if x[8] <=
#     10.0 else 0.0) if x[2] <= 44031.0 else 0.1) if x[3] <= 5.5 else 0.0) if
#     x[0] <= 12750.0 else 0.0) if x[2] <= 51328.0 else ((((0.1 if x[6] <=
#     94.91500091552734 else 0.0) if x[8] <= 9.5 else ((((0.1 if x[6] <=
#     165.31499862670898 else 0.0) if x[1] <= 38380.5 else ((0.0 if x[0] <=
#     9450.0 else 0.0 if x[8] <= 15.0 else 0.1) if x[6] <= 94.76499938964844 else
#     0.1 if x[1] <= 70237.0 else 0.0) if x[6] <= 102.81999969482422 else (
#     0.0 if x[14] <= 0.5 else 0.1) if x[8] <= 13.5 else 0.0 if x[1] <=
#     85646.5 else 0.1 if x[0] <= 5850.0 else 0.0) if x[0] <= 9550.0 else (
#     0.0 if x[0] <= 18550.0 else (0.0 if x[9] <= 36.68649864196777 else 0.1) if
#     x[0] <= 18650.0 else 0.0 if x[1] <= 78567.0 else 0.1 if x[2] <=
#     100300.0 else 0.1 if x[1] <= 79812.0 else 0.0) if x[1] <= 114716.0 else
#     0.1 if x[1] <= 116292.5 else (0.0 if x[8] <= 24.5 else 0.1) if x[3] <=
#     0.5 else (0.1 if x[8] <= 19.0 else 0.0) if x[2] <= 167649.5 else 0.0) if
#     x[5] <= 1.5 else (0.0 if x[8] <= 33.0 else 0.0 if x[9] <=
#     32.953999519348145 else 0.1) if x[2] <= 113133.0 else (0.0 if x[3] <=
#     17.0 else 0.1) if x[14] <= 0.5 else 0.1) if x[9] <= 43.70450019836426 else
#     0.1 if x[7] <= 0.5 else 0.0) if x[12] <= 0.5 else ((((0.0 if x[6] <=
#     196.91000366210938 else 0.1) if x[8] <= 15.0 else (0.1 if x[3] <= 9.0 else
#     0.0) if x[0] <= 9050.0 else 0.0) if x[8] <= 36.0 else 0.1) if x[5] <=
#     0.5 else 0.0 if x[0] <= 10050.0 else 0.0 if x[9] <= 33.26250076293945 else
#     0.0 if x[3] <= 2.5 else 0.1) if x[2] <= 228168.0 else 0.1) if x[17] <=
#     0.5 else (0.1 if x[2] <= 80481.5 else 0.0) if x[6] <= 272.1500015258789
#      else 0.1) if x[8] <= 60.0 else 0.1) if x[7] <= 3.5 else ((0.0 if x[15] <=
#     0.5 else 0.1 if x[1] <= 59620.0 else 0.0) if x[1] <= 102969.5 else 0.1) if
#     x[9] <= 39.01449966430664 else 0.1 if x[6] <= 166.7750015258789 else
#     0.0) if x[2] <= 296497.5 else 0.0 if x[3] <= 3.0 else 0.1 if x[5] <=
#     0.5 else 0.0) if x[5] <= 3.5 else 0.1 if x[8] <= 33.0 else 0.0) if x[9] <=
#     45.13100051879883 else 0.1 if x[6] <= 297.86500549316406 else 0.1 if x[
#     0] <= 22100.0 else 0.0) + ((((((0.1 if x[0] <= 8100.0 else (0.0 if x[15
#     ] <= 0.5 else 0.1 if x[8] <= 6.0 else 0.0) if x[4] <= 0.5 else 0.1) if
#     x[13] <= 0.5 else 0.1) if x[8] <= 9.5 else (((0.1 if x[1] <= 67617.5 else
#     0.0) if x[6] <= 101.53499984741211 else (0.1 if x[1] <= 18298.0 else ((
#     (0.1 if x[3] <= 1.5 else 0.0) if x[8] <= 13.5 else 0.0) if x[5] <= 1.5 else
#     0.1 if x[1] <= 45249.5 else 0.0) if x[2] <= 121453.5 else 0.1 if x[6] <=
#     174.27000427246094 else 0.0) if x[5] <= 2.5 else 0.1 if x[3] <= 12.0 else
#     0.0) if x[0] <= 8950.0 else (0.1 if x[11] <= 0.5 else 0.0) if x[6] <=
#     55.86000061035156 else (((((((0.0 if x[11] <= 0.5 else 0.1) if x[3] <=
#     2.5 else 0.0) if x[17] <= 0.5 else 0.1) if x[4] <= 1.5 else 0.1) if x[8
#     ] <= 12.5 else ((((0.0 if x[8] <= 17.5 else 0.1 if x[0] <= 12600.0 else
#     0.0) if x[12] <= 0.5 else 0.1 if x[8] <= 15.0 else 0.0) if x[8] <= 18.5
#      else 0.0) if x[7] <= 2.5 else 0.1 if x[1] <= 42296.5 else 0.0) if x[1] <=
#     129593.0 else (0.0 if x[0] <= 12100.0 else 0.1) if x[2] <= 167831.0 else
#     0.0) if x[9] <= 42.85949897766113 else 0.1 if x[9] <= 42.92849922180176
#      else 0.0) if x[8] <= 34.5 else ((0.1 if x[3] <= 10.5 else 0.0) if x[1] <=
#     35284.0 else 0.0) if x[6] <= 278.5500030517578 else (0.0 if x[0] <=
#     22250.0 else 0.1) if x[6] <= 313.9949951171875 else 0.0) if x[5] <= 1.5
#      else (0.0 if x[1] <= 71948.0 else 0.1 if x[1] <= 80500.5 else 0.1 if x
#     [0] <= 11350.0 else 0.0) if x[2] <= 146349.0 else 0.1) if x[8] <= 60.0 else
#     0.1) if x[7] <= 3.5 else ((0.0 if x[8] <= 7.5 else 0.1) if x[2] <=
#     69583.0 else ((0.0 if x[3] <= 18.5 else 0.0 if x[2] <= 119682.5 else
#     0.1) if x[7] <= 12.0 else 0.1) if x[8] <= 40.0 else 0.1) if x[5] <= 0.5
#      else 0.1) if x[5] <= 3.5 else 0.0 if x[9] <= 29.273499488830566 else
#     0.1) if x[9] <= 43.70450019836426 else ((0.0 if x[8] <= 18.0 else 0.1) if
#     x[9] <= 44.2814998626709 else 0.1 if x[6] <= 239.91500091552734 else
#     0.1 if x[8] <= 29.0 else 0.0) if x[6] <= 294.9649963378906 else 0.0) +
#     ((((0.1 if x[0] <= 7000.0 else 0.0) if x[1] <= 26483.5 else (0.0 if x[0
#     ] <= 6600.0 else 0.1) if x[3] <= 7.0 else ((0.1 if x[1] <= 33165.0 else
#     0.0) if x[0] <= 12300.0 else 0.0) if x[9] <= 40.971500396728516 else
#     0.1) if x[8] <= 8.5 else ((((((0.0 if x[2] <= 38268.5 else 0.1) if x[3] <=
#     5.5 else 0.0) if x[7] <= 2.5 else 0.1 if x[1] <= 134508.0 else 0.0) if
#     x[2] <= 46690.0 else (((((((((0.1 if x[2] <= 76635.0 else 0.0) if x[6] <=
#     58.40999984741211 else 0.1 if x[9] <= 23.051499366760254 else ((0.0 if
#     x[11] <= 0.5 else (0.0 if x[3] <= 7.5 else 0.1) if x[7] <= 0.5 else 0.0
#     ) if x[5] <= 0.5 else 0.0 if x[3] <= 6.5 else 0.1) if x[3] <= 13.5 else
#     0.1 if x[3] <= 14.5 else 0.0) if x[1] <= 66414.5 else 0.0 if x[6] <=
#     94.15999984741211 else 0.1) if x[2] <= 82293.0 else 0.1 if x[0] <=
#     17700.0 else 0.0) if x[2] <= 85253.5 else 0.0) if x[7] <= 8.5 else 0.1) if
#     x[16] <= 0.5 else 0.1) if x[5] <= 2.5 else 0.1) if x[8] <= 36.5 else
#     0.1) if x[6] <= 107.80999755859375 else (((0.0 if x[11] <= 0.5 else 0.1
#     ) if x[9] <= 10.479499816894531 else ((0.0 if x[1] <= 56842.5 else 0.1) if
#     x[0] <= 6150.0 else 0.0 if x[12] <= 0.5 else (0.0 if x[9] <=
#     27.679999351501465 else 0.1) if x[9] <= 27.792499542236328 else 0.0) if
#     x[9] <= 35.09649848937988 else 0.1 if x[9] <= 35.132999420166016 else (
#     (((((0.0 if x[2] <= 59641.5 else 0.1) if x[1] <= 34433.0 else 0.0 if x[
#     1] <= 94354.5 else 0.1 if x[2] <= 107137.5 else 0.0 if x[14] <= 0.5 else
#     0.0 if x[8] <= 22.5 else 0.1) if x[3] <= 3.5 else 0.0) if x[5] <= 0.5 else
#     (0.0 if x[7] <= 4.0 else 0.1) if x[8] <= 30.5 else 0.0 if x[0] <=
#     11750.0 else 0.1) if x[9] <= 44.460500717163086 else 0.1) if x[6] <=
#     306.60499572753906 else 0.0 if x[8] <= 28.5 else 0.0 if x[1] <= 85053.5
#      else 0.1 if x[0] <= 27750.0 else 0.0) if x[4] <= 0.5 else 0.1 if x[2] <=
#     64431.5 else 0.0 if x[2] <= 104419.0 else 0.1 if x[1] <= 85831.0 else
#     0.0) if x[8] <= 42.5 else (0.0 if x[9] <= 43.02949905395508 else 0.1) if
#     x[0] <= 26800.0 else 0.1 if x[6] <= 342.4300079345703 else 0.0) if x[2] <=
#     491199.0 else 0.1) if x[5] <= 3.5 else 0.1 if x[8] <= 33.0 else 0.1 if
#     x[10] <= 0.5 else 0.0) if x[8] <= 59.5 else 0.1) if x[4] <= 3.5 else
#     0.1) if x[9] <= 45.48349952697754 else 0.1) + (((0.1 if x[0] <= 3250.0 else
#     (((((0.1 if x[9] <= 38.74300003051758 else 0.1 if x[1] <= 28130.0 else
#     0.0) if x[3] <= 7.0 else 0.0 if x[14] <= 0.5 else 0.1 if x[8] <= 24.5 else
#     0.0) if x[1] <= 40868.5 else ((0.0 if x[0] <= 8550.0 else 0.1) if x[6] <=
#     69.06000137329102 else (0.0 if x[2] <= 119867.5 else 0.1 if x[2] <=
#     122578.5 else 0.0) if x[16] <= 0.5 else 0.1 if x[6] <=
#     111.8849983215332 else 0.0) if x[4] <= 0.5 else 0.1 if x[6] <=
#     160.40499877929688 else 0.0) if x[0] <= 9950.0 else 0.1 if x[6] <=
#     16.509999752044678 else ((((((0.0 if x[0] <= 12150.0 else 0.1) if x[0] <=
#     12550.0 else 0.0 if x[13] <= 0.5 else 0.1 if x[1] <= 50043.5 else 0.0) if
#     x[1] <= 99024.0 else 0.0 if x[9] <= 38.09700012207031 else 0.1) if x[6] <=
#     80.16500091552734 else 0.1) if x[6] <= 80.27000045776367 else (((0.0 if
#     x[9] <= 21.354999542236328 else 0.1) if x[3] <= 4.5 else 0.0) if x[2] <=
#     48293.5 else (((0.0 if x[1] <= 56646.0 else 0.1) if x[6] <=
#     94.79000091552734 else 0.0) if x[8] <= 9.5 else 0.0) if x[6] <=
#     199.66500091552734 else 0.1 if x[6] <= 199.84000396728516 else (0.1 if
#     x[6] <= 230.52000427246094 else 0.0) if x[3] <= 0.5 else ((0.0 if x[6] <=
#     202.59000396728516 else 0.1) if x[6] <= 202.84500122070312 else 0.0 if
#     x[8] <= 35.5 else 0.0 if x[6] <= 300.4100036621094 else 0.1 if x[8] <=
#     39.0 else 0.0) if x[5] <= 1.5 else 0.0 if x[2] <= 140492.0 else 0.1) if
#     x[12] <= 0.5 else (((((0.0 if x[6] <= 228.1500015258789 else 0.1) if x[
#     8] <= 15.0 else 0.0) if x[5] <= 1.5 else 0.0 if x[6] <=
#     178.18499755859375 else 0.1) if x[8] <= 30.0 else 0.0 if x[2] <=
#     101321.5 else 0.1) if x[5] <= 2.5 else 0.1 if x[11] <= 0.5 else 0.0) if
#     x[0] <= 44650.0 else 0.1) if x[9] <= 43.70450019836426 else 0.0 if x[8] <=
#     21.0 else 0.1) if x[6] <= 901.3450012207031 else 0.1) if x[2] <=
#     301876.5 else 0.1) if x[7] <= 3.5 else ((0.0 if x[0] <= 12150.0 else
#     0.1) if x[2] <= 69583.0 else ((0.0 if x[3] <= 18.5 else 0.0 if x[4] <=
#     0.5 else 0.1) if x[8] <= 42.5 else 0.1) if x[7] <= 12.0 else 0.1) if x[
#     5] <= 0.5 else 0.1 if x[0] <= 23500.0 else 0.0) if x[5] <= 3.5 else 0.1
#     ) if x[9] <= 45.13100051879883 else (0.1 if x[3] <= 4.5 else 0.0) if x[
#     8] <= 18.0 else 0.1) + (((0.1 if x[0] <= 2650.0 else (((0.0 if x[6] <=
#     171.16499710083008 else 0.1 if x[6] <= 255.99999237060547 else 0.0) if
#     x[3] <= 2.5 else ((0.0 if x[2] <= 48468.0 else 0.1) if x[8] <= 5.5 else
#     0.1) if x[0] <= 15000.0 else 0.0 if x[6] <= 664.4799880981445 else 0.1) if
#     x[8] <= 8.5 else 0.1 if x[6] <= 43.525001525878906 else ((0.0 if x[0] <=
#     22250.0 else 0.1) if x[6] <= 52.83500099182129 else ((0.1 if x[3] <=
#     5.5 else 0.0) if x[2] <= 39600.0 else ((0.0 if x[7] <= 0.5 else 0.1 if
#     x[9] <= 34.257999420166016 else 0.0) if x[0] <= 6850.0 else 0.1) if x[0
#     ] <= 6950.0 else (((0.1 if x[8] <= 25.0 else 0.0) if x[2] <= 51355.0 else
#     0.1 if x[6] <= 59.63999938964844 else ((0.1 if x[3] <= 0.5 else 0.0) if
#     x[1] <= 32765.5 else 0.0 if x[0] <= 18050.0 else ((0.1 if x[13] <= 0.5 else
#     0.0) if x[2] <= 77055.0 else 0.0) if x[14] <= 0.5 else (0.0 if x[7] <=
#     2.5 else 0.1 if x[6] <= 209.11000442504883 else 0.0) if x[1] <= 89887.5
#      else 0.1 if x[6] <= 182.4749984741211 else 0.0) if x[6] <=
#     323.8800048828125 else 0.1) if x[3] <= 3.5 else (((0.0 if x[3] <= 7.5 else
#     0.1 if x[15] <= 0.5 else 0.0) if x[6] <= 89.32999801635742 else 0.0) if
#     x[0] <= 9550.0 else (0.0 if x[0] <= 12150.0 else 0.0 if x[14] <= 0.5 else
#     0.1) if x[0] <= 12250.0 else 0.0) if x[1] <= 197597.5 else 0.0 if x[0] <=
#     43000.0 else 0.1) if x[7] <= 3.5 else 0.1 if x[2] <= 71066.5 else 0.0 if
#     x[13] <= 0.5 else 0.0 if x[3] <= 12.5 else 0.1) if x[8] <= 34.5 else ((
#     0.0 if x[7] <= 3.5 else 0.1 if x[6] <= 232.31999969482422 else 0.0) if
#     x[6] <= 257.3899917602539 else (0.1 if x[7] <= 3.5 else 0.0) if x[6] <=
#     313.9949951171875 else 0.0) if x[12] <= 0.5 else 0.0 if x[9] <=
#     33.92400074005127 else 0.1) if x[2] <= 488947.5 else 0.1) if x[5] <=
#     0.5 else (0.1 if x[0] <= 5700.0 else ((0.1 if x[6] <=
#     27.470000743865967 else 0.0 if x[1] <= 74018.5 else 0.1 if x[1] <=
#     74159.0 else 0.0 if x[3] <= 12.5 else 0.1 if x[7] <= 0.5 else 0.0) if x
#     [8] <= 57.0 else 0.1) if x[2] <= 110246.0 else 0.0 if x[7] <= 0.5 else
#     (0.1 if x[6] <= 226.59500122070312 else 0.0) if x[3] <= 6.5 else (0.1 if
#     x[6] <= 170.18500518798828 else 0.0) if x[6] <= 302.5900115966797 else
#     0.1) if x[7] <= 3.5 else 0.1 if x[0] <= 23450.0 else 0.0) if x[5] <=
#     3.5 else 0.1 if x[8] <= 33.0 else 0.0 if x[5] <= 5.5 else 0.1) if x[9] <=
#     45.48349952697754 else 0.1))

# %%
y_pred=rf_model.predict(X_train)
np.sqrt(mean_squared_error(y_train,y_pred))
# Out:
# 0.08526619412100572

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1374
#            1       1.00      0.92      0.96       139
#
#     accuracy                           0.99      1513
#    macro avg       1.00      0.96      0.98      1513
# weighted avg       0.99      0.99      0.99      1513

# %% [markdown]
# MODEL TUNING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2018 entries, 153 to 3549
# Data columns (total 13 columns):
# bad        2018 non-null int64
# loan       2018 non-null int64
# mortdue    2018 non-null float64
# value      2018 non-null float64
# reason     2018 non-null object
# job        2018 non-null object
# yoj        2018 non-null float64
# derog      2018 non-null float64
# delinq     2018 non-null float64
# clage      2018 non-null float64
# ninq       2018 non-null float64
# clno       2018 non-null float64
# debtinc    2018 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 220.7+ KB

# %%
rf_params = {"max_depth": [2,5,8,10],
             "max_features": [3,7,13],
             "min_samples_split": [5,10],
             "n_estimators" : [100, 200, 500]}

# %%
rf_cv_model = GridSearchCV(rf_model, 
                           rf_params, 
                           cv=10, 
                           n_jobs=-1, 
                           verbose=2)
rf_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  2.6min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': [2, 5, 8, 10], 'max_features': [3, 7, 13],
#                          'min_samples_split': [5, 10],
#                          'n_estimators': [100, 200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
rf_cv_model.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 7,
#  'min_samples_split': 5,
#  'n_estimators': 500}

# %%
rf_tuned = RandomForestClassifier(max_depth  = 10, 
                                 max_features = 7, 
                                 n_estimators =500,
                                 min_samples_split=5)

# %%
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=10, max_features=7, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred= rf_tuned.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 0.19409661605715353

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1374
#            1       1.00      0.59      0.74       139
#
#     accuracy                           0.96      1513
#    macro avg       0.98      0.79      0.86      1513
# weighted avg       0.96      0.96      0.96      1513

# %%
rf_tuned.fit(X_test, y_test)
y_pred= rf_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.13349824784699543

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       466
#            1       1.00      0.77      0.87        39
#
#     accuracy                           0.98       505
#    macro avg       0.99      0.88      0.93       505
# weighted avg       0.98      0.98      0.98       505

# %%
Importance = pd.DataFrame({"Importance": rf_tuned.feature_importances_*100},
                         index = X_train.columns)

# %%
Importance.sort_values(by = "Importance", 
                       axis = 0, 
                       ascending = True).plot(kind ="barh", color = "r")

plt.xlabel("Değişken Önem Düzeyleri")
# Out:
# Text(0.5, 0, 'Değişken Önem Düzeyleri')

# %% [markdown]
# # YAPAY SİNİR AĞLARI

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

print("X_train", X_train.shape)

print("y_train",y_train.shape)

print("X_test",X_test.shape)

print("y_test",y_test.shape)

training = df.copy()

print("training", training.shape)
# Out:
# X_train (1513, 18)
# y_train (1513,)
# X_test (505, 18)
# y_test (505,)
# training (2018, 13)

# %%
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100,20)).fit(X_train, y_train)
# Out:
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# TAHMİN

# %%
y_pred= mlp_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 0.29870838943143485

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.9107732980832782

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      1374
#            1       1.00      0.03      0.06       139
#
#     accuracy                           0.91      1513
#    macro avg       0.96      0.51      0.50      1513
# weighted avg       0.92      0.91      0.87      1513

# %% [markdown]
# MODEL TUNING

# %%
mlp_params = {'alpha': [0.1, 0.01,0.02,0.005],
             'hidden_layer_sizes': [(20,20),(100,50,150),(300,200,150)],
             'activation': ['relu','logistic']}

# %%
mlp_cv_model = GridSearchCV(mlp_model, mlp_params, cv = 10)

# %%
mlp_cv_model.fit(X_train, y_train)
# Out:
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=MLPClassifier(activation='relu', alpha=0.0001,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
#                                      epsilon=1e-08,
#                                      hidden_layer_sizes=(100, 20),
#                                      learning_rate='constant',
#                                      learning_rate_init=0.001, max_iter=200,
#                                      momentum=0.9, n_iter_no_change=10,
#                                      nesterovs_momentum=True, power_t=0.5,
#                                      random_state=None, shuffle=True,
#                                      solver='adam', tol=0.0001,
#                                      validation_fraction=0.1, verbose=False,
#                                      warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'activation': ['relu', 'logistic'],
#                          'alpha': [0.1, 0.01, 0.02, 0.005],
#                          'hidden_layer_sizes': [(20, 20), (100, 50, 150),
#                                                 (300, 200, 150)]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
mlp_cv_model.best_params_
# Out:
# {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (300, 200, 150)}

# %%
mlp_tuned = MLPClassifier(alpha = 0.1, hidden_layer_sizes = (20,20))

# %%
mlp_tuned.fit(X_train, y_train)
# Out:
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(20, 20), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred= mlp_tuned.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 0.3159140997805971

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.900198281559815

# %%
mlp_tuned.fit(X_test, y_test)
# Out:
# C:\Users\karde\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(20, 20), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred= mlp_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.2918021844529015

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       466
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.91       505
#    macro avg       0.46      0.50      0.48       505
# weighted avg       0.85      0.91      0.88       505

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9148514851485149
